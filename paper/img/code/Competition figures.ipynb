# %%
# %pylab inline

plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 14.0
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import math_biol as mb
import pylab as pl

# %%
dims = 10
w = 0.1
p = [-0.3, 0.0, 0.3]
txt = ['Intra-specific competition dominates \n ($ \epsilon < 0 $)', 
       'Near-neutral competition \n ($ \epsilon = 0 $)', 
       'Inter-specific competition dominates \n ($ \epsilon > 0 $)']

xlab = 'Species id'
ylab = 'Species id'

cbTicks = [0, 1, 2]

savePngs = True

# %%
plt.matshow(mb.competition_matrix(dims, p[0], w=w, mode='sliding_window'), cmap=cm.RdYlGn, vmin=0, vmax=2)
plt.colorbar();
plt.title(txt[0]);

plt.xlabel(xlab)
plt.ylabel(ylab)

ax = plt.gca()

# Major ticks
ax.set_xticks(np.arange(0, 10, 1));
ax.set_yticks(np.arange(0, 10, 1));

# Labels for major ticks
ax.set_xticklabels(np.arange(1, 11, 1));
ax.set_yticklabels(np.arange(1, 11, 1));

# Minor ticks
ax.set_xticks(np.arange(-.5, 10, 1), minor=True);
ax.set_yticks(np.arange(-.5, 10, 1), minor=True);

# Gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

if savePngs:
    plt.savefig('..\epsilon_negative.png')

# %%
plt.matshow(mb.competition_matrix(dims, p[1], w=w, mode='sliding_window'), cmap=cm.RdYlGn, vmin=0, vmax=2)
plt.colorbar();
plt.title(txt[1]);

plt.xlabel(xlab)
plt.ylabel(ylab)

ax = plt.gca()

# Major ticks
ax.set_xticks(np.arange(0, 10, 1));
ax.set_yticks(np.arange(0, 10, 1));

# Labels for major ticks
ax.set_xticklabels(np.arange(1, 11, 1));
ax.set_yticklabels(np.arange(1, 11, 1));

# Minor ticks
ax.set_xticks(np.arange(-.5, 10, 1), minor=True);
ax.set_yticks(np.arange(-.5, 10, 1), minor=True);

# Gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

if savePngs:
    plt.savefig('..\epsilon_neutral.png')

# %%
plt.matshow(mb.competition_matrix(dims, p[2], w=w, mode='sliding_window'), cmap=cm.RdYlGn, vmin=0, vmax=2)
plt.colorbar();
plt.title(txt[2]);

plt.xlabel(xlab)
plt.ylabel(ylab)

ax = plt.gca()

# Major ticks
ax.set_xticks(np.arange(0, 10, 1));
ax.set_yticks(np.arange(0, 10, 1));

# Labels for major ticks
ax.set_xticklabels(np.arange(1, 11, 1));
ax.set_yticklabels(np.arange(1, 11, 1));

# Minor ticks
ax.set_xticks(np.arange(-.5, 10, 1), minor=True);
ax.set_yticks(np.arange(-.5, 10, 1), minor=True);

# Gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

if savePngs:
    plt.savefig('..\epsilon_positive.png')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.rcParams['figure.figsize'] = (12, 3.7)

subplot(131)
im = imshow(mb.competition_matrix(dims, p[0], w=w, mode='sliding_window'), cmap=cm.RdYlGn, vmin=0, vmax=2)
plt.title(txt[0], size=12);

plt.xlabel(xlab)
plt.ylabel(ylab)

ax = plt.gca()

# Major ticks
ax.set_xticks(np.arange(0, 10, 1));
ax.set_yticks(np.arange(0, 10, 1));

# Labels for major ticks
ax.set_xticklabels(np.arange(1, 11, 1));
ax.set_yticklabels(np.arange(1, 11, 1));

# Minor ticks
ax.set_xticks(np.arange(-.5, 10, 1), minor=True);
ax.set_yticks(np.arange(-.5, 10, 1), minor=True);

# Gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=1)


# -----

subplot(132)
im = imshow(mb.competition_matrix(dims, p[1], w=w, mode='sliding_window'), cmap=cm.RdYlGn, vmin=0, vmax=2)
plt.title(txt[1], size=12);

plt.xlabel(xlab)

ax = plt.gca()

# Major ticks
ax.set_xticks(np.arange(0, 10, 1));
ax.set_yticks(np.arange(0, 10, 1));

# Labels for major ticks
ax.set_xticklabels(np.arange(1, 11, 1));
ax.set_yticklabels(np.arange(1, 11, 1));

# Minor ticks
ax.set_xticks(np.arange(-.5, 10, 1), minor=True);
ax.set_yticks(np.arange(-.5, 10, 1), minor=True);

# Gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=1)

# -----

subplot(133)
im = imshow(mb.competition_matrix(dims, p[2], w=w, mode='sliding_window'), cmap=cm.RdYlGn, vmin=0, vmax=2)
plt.title(txt[2], size=12);

plt.xlabel(xlab)

ax = plt.gca()

# Major ticks
ax.set_xticks(np.arange(0, 10, 1));
ax.set_yticks(np.arange(0, 10, 1));

# Labels for major ticks
ax.set_xticklabels(np.arange(1, 11, 1));
ax.set_yticklabels(np.arange(1, 11, 1));

# Minor ticks
ax.set_xticks(np.arange(-.5, 10, 1), minor=True);
ax.set_yticks(np.arange(-.5, 10, 1), minor=True);

# Gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=1)

# -----
fig = plt.gcf()
fig.subplots_adjust(right=0.82)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax, ticks=cbTicks)

# -----
#plt.suptitle('Competition matrices');


# -----
if savePngs:
    plt.savefig('..\epsilon_all.png')
    #plt.savefig('all.svg')
    #plt.savefig('all.pdf')
